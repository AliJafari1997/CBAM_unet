# %%
# !git clone https://github.com/Ali-1329/CBAM_unet.git
# Out:
# Cloning into 'CBAM_unet'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 45 (delta 18), reused 6 (delta 0), pack-reused 0
# Unpacking objects: 100% (45/45), done.

# %%
cd /content/CBAM_unet
# Out:
# /content/CBAM_unet

# %%
ls
# Out:
# attention.py     data.py     model_1.py  predict.py        train.py
# CBAM_Unet.ipynb  metrics.py  model.py    stop_training.py  utils.py

# %%
# !nvidia-smi
# Out:
# Fri Mar  4 08:37:54 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8    30W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python train.py
# Out:
# 2022-03-04 08:38:26.650954: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Epoch 1/100
# 368/368 [==============================] - 806s 2s/step - loss: 0.7143 - recall: 0.7762 - precision: 0.2086 - dice_coef: 0.2859 - mean_io_u: 0.4505 - val_loss: 0.7390 - val_recall: 0.4883 - val_precision: 0.3631 - val_dice_coef: 0.2566 - val_mean_io_u: 0.4535 - lr: 1.0000e-04
# Epoch 2/100
# 368/368 [==============================] - 391s 1s/step - loss: 0.6111 - recall: 0.7882 - precision: 0.3534 - dice_coef: 0.3891 - mean_io_u: 0.4505 - val_loss: 0.6054 - val_recall: 0.7292 - val_precision: 0.4244 - val_dice_coef: 0.3901 - val_mean_io_u: 0.4555 - lr: 1.0000e-04
# Epoch 3/100
# ...
